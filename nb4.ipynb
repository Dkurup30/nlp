# %%
# 🧩 Install Dependencies (only once)
# %pip install transformers datasets sentence-transformers langdetect googletrans==4.0.0-rc1 scikit-learn hf_xet
# Out:
# Requirement already satisfied: transformers in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (4.51.3)
# Requirement already satisfied: datasets in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (3.5.0)
# Requirement already satisfied: sentence-transformers in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (4.1.0)
# Requirement already satisfied: langdetect in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (1.0.9)
# Requirement already satisfied: googletrans==4.0.0-rc1 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (4.0.0rc1)
# Requirement already satisfied: scikit-learn in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: hf_xet in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (1.0.3)
# Requirement already satisfied: httpx==0.13.3 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Requirement already satisfied: hstspreload in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Requirement already satisfied: filelock in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from datasets) (3.11.16)
# Requirement already satisfied: torch>=1.11.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scipy in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (1.12.0)
# Requirement already satisfied: Pillow in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: six in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from langdetect) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from requests->transformers) (2.2.2)
# Requirement already satisfied: networkx in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (69.2.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kurup\appdata\local\programs\python\python312\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\kurup\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\kurup\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (c:\Users\kurup\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForTokenClassification
from sentence_transformers import SentenceTransformer
from langdetect import detect
import json

# %%
with open("farmer_data.json", "r", encoding='utf-8') as f:
    farmer_ds = json.load(f)

sense_inventory = {
    "plant_1": "a living organism such as a tree or vegetable",
    "plant_2": "a manufacturing facility",
    "spray_1": "to apply a liquid in mist form",
    "spray_2": "a container for spraying liquid",
    "feed_1": "to give food to animals",
    "feed_2": "material supplied to a machine"
}

# %%
ner_model_name = "Davlan/bert-base-multilingual-cased-ner-hrl"
tokenizer = AutoTokenizer.from_pretrained(ner_model_name)
ner_model = AutoModelForTokenClassification.from_pretrained(ner_model_name)
ner_pipeline = pipeline("ner", model=ner_model, tokenizer=tokenizer, grouped_entities=True)
wsd_model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Device set to use cpu

# %%
def detect_language(text):
    try:
        return detect(text)
    except:
        return "unknown"


from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

def disambiguate_word(context_sentence, word, sense_inventory):
    senses = [k for k in sense_inventory if k.startswith(word)]
    if not senses:
        return None

    context_embedding = model.encode(context_sentence, convert_to_tensor=True)
    best_sense, best_score = None, -1
    for sense_key in senses:
        gloss = sense_inventory[sense_key]
        gloss_embedding = model.encode(gloss, convert_to_tensor=True)
        score = util.pytorch_cos_sim(context_embedding, gloss_embedding).item()
        if score > best_score:
            best_score = score
            best_sense = sense_key
    return best_sense

# %%
def fallback_ner(text):
    keywords = {
        "LOC": ["village", "Punjab", "Maharashtra", "pond", "field"],
        "PROD": ["pesticide", "spray", "crops", "wheat", "rice", "urea"],
        "ANIMAL": ["goats", "chickens", "fish"],
        "DISEASE": ["blight", "whiteflies", "झुलसा रोग"]
    }
    entities = []
    for label, terms in keywords.items():
        for term in terms:
            if term.lower() in text.lower():
                entities.append((term, label))
    return entities

# %%
for data in farmer_ds:
    query = data['question']
    response = data['answer']
    language = detect(query)

    # NER
    ner_entities = ner_pipeline(query)
    clean_ner = [(ent['word'], ent['entity_group']) for ent in ner_entities]
    fallback_entities = fallback_ner(query)
    all_entities = list({(w, l) for (w, l) in clean_ner + fallback_entities})

    # WSD
    disambigs = {}
    for word in data['ambiguous']:
        sense = disambiguate_word(query, word, sense_inventory)
        if sense:
            disambigs[word] = sense

    # 🖨️ Display
    print(f" User Query: {query}")
    print(f" Chatbot Answer: {response}")
    print(f" Detected Language: {language}")
    print(f"\n\n NER Entities: {all_entities}")
    if disambigs:
        for word, sense in disambigs.items():
            print(f"\n Disambiguated '{word}': {sense}")
    print("\n" + "-"*80 + "\n")
# Out:
#  User Query: The plant is not growing properly.
#  Chatbot Answer: Ensure it gets enough water and sunlight.
#  Detected Language: en
#
#
#  NER Entities: []
#
#  Disambiguated 'plant': plant_1
#
# --------------------------------------------------------------------------------
#
#  User Query: There is a pesticide plant near my village.
#  Chatbot Answer: Yes, it's a pesticide manufacturing facility.
#  Detected Language: en
#
#
#  NER Entities: [('pesticide', 'PROD'), ('village', 'LOC')]
#
#  Disambiguated 'plant': plant_1
#
# --------------------------------------------------------------------------------
#
#  User Query: Spray the pesticide in the evening.
#  Chatbot Answer: Evening spray reduces evaporation loss.
#  Detected Language: en
#
#
#  NER Entities: [('pesticide', 'PROD'), ('spray', 'PROD')]
#
#  Disambiguated 'spray': spray_2
#
# --------------------------------------------------------------------------------
#
#  User Query: I bought a new spray for my crops.
#  Chatbot Answer: Check the nozzle size for better coverage.
#  Detected Language: en
#
#
#  NER Entities: [('spray', 'PROD'), ('crops', 'PROD')]
#
#  Disambiguated 'spray': spray_2
#
# --------------------------------------------------------------------------------
#
#  User Query: How should I feed my goats?
#  Chatbot Answer: Provide dry fodder and clean water twice daily.
#  Detected Language: en
#
#
#  NER Entities: [('goats', 'ANIMAL')]
#
#  Disambiguated 'feed': feed_1
#
# --------------------------------------------------------------------------------
#
#  User Query: The machine feed is jammed again.
#  Chatbot Answer: Lubricate the rollers to avoid jamming.
#  Detected Language: en
#
#
#  NER Entities: []
#
#  Disambiguated 'feed': feed_2
#
# --------------------------------------------------------------------------------
#
#  User Query: I planted wheat last week.
#  Chatbot Answer: Good, irrigate 21 days after sowing.
#  Detected Language: en
#
#
#  NER Entities: [('wheat', 'PROD')]
#
# --------------------------------------------------------------------------------
#
#  User Query: मुझे गेहूं की बुवाई कब करनी चाहिए?
#  Chatbot Answer: अक्टूबर से नवंबर का समय उपयुक्त होता है।
#  Detected Language: hi
#
#
#  NER Entities: []
#
# --------------------------------------------------------------------------------
#
#  User Query: Is urea good for rice?
#  Chatbot Answer: Yes, apply it in split doses for better uptake.
#  Detected Language: en
#
#
#  NER Entities: [('urea', 'PROD'), ('rice', 'PROD')]
#
# --------------------------------------------------------------------------------
#
#  User Query: My cotton crop has whiteflies.
#  Chatbot Answer: Use neem oil or Imidacloprid spray.
#  Detected Language: en
#
#
#  NER Entities: [('whiteflies', 'DISEASE')]
#
# --------------------------------------------------------------------------------
#
#  User Query: मेरे टमाटर में झुलसा रोग हो गया है।
#  Chatbot Answer: Mancozeb फफूंदनाशी का छिड़काव करें।
#  Detected Language: hi
#
#
#  NER Entities: [('झुलसा रोग', 'DISEASE')]
#
# --------------------------------------------------------------------------------
#
#  User Query: I saw a plant outside the factory.
#  Chatbot Answer: Please specify if it's a tree or an industrial unit.
#  Detected Language: en
#
#
#  NER Entities: []
#
#  Disambiguated 'plant': plant_2
#
# --------------------------------------------------------------------------------
#
#  User Query: Spray can is leaking.
#  Chatbot Answer: Check the seal and replace the can if needed.
#  Detected Language: tl
#
#
#  NER Entities: [('spray', 'PROD')]
#
#  Disambiguated 'spray': spray_2
#
# --------------------------------------------------------------------------------
#
#  User Query: How do I feed fish in a pond?
#  Chatbot Answer: Use pellet feed twice a day.
#  Detected Language: en
#
#
#  NER Entities: [('pond', 'LOC'), ('fish', 'ANIMAL')]
#
#  Disambiguated 'feed': feed_1
#
# --------------------------------------------------------------------------------
#
#  User Query: Tomato plants need calcium.
#  Chatbot Answer: Use calcium nitrate foliar spray.
#  Detected Language: en
#
#
#  NER Entities: []
#
# --------------------------------------------------------------------------------
#
#  User Query: पंजाब में धान की रोपाई कब शुरू होती है?
#  Chatbot Answer: जून के मध्य से जुलाई तक रोपाई की जाती है।
#  Detected Language: hi
#
#
#  NER Entities: [('पंजाब', 'LOC')]
#
# --------------------------------------------------------------------------------
#
#  User Query: There is a feed blockage in the tractor.
#  Chatbot Answer: Check the input chute for debris.
#  Detected Language: en
#
#
#  NER Entities: []
#
#  Disambiguated 'feed': feed_1
#
# --------------------------------------------------------------------------------
#
#  User Query: Where can I plant sugarcane?
#  Chatbot Answer: Sugarcane thrives in tropical regions with rich soil.
#  Detected Language: en
#
#
#  NER Entities: []
#
#  Disambiguated 'plant': plant_1
#
# --------------------------------------------------------------------------------
#
#  User Query: Should I spray pesticide during rain?
#  Chatbot Answer: Avoid spraying during rain to prevent runoff.
#  Detected Language: en
#
#
#  NER Entities: [('pesticide', 'PROD'), ('spray', 'PROD')]
#
#  Disambiguated 'spray': spray_2
#
# --------------------------------------------------------------------------------
#
#  User Query: मुझे अच्छी मक्का की किस्म बताइए।
#  Chatbot Answer: आप 'प्रभात' और 'एचएम-4' किस्में ले सकते हैं।
#  Detected Language: hi
#
#
#  NER Entities: []
#
# --------------------------------------------------------------------------------
#
#  User Query: What time is best to feed chickens?
#  Chatbot Answer: Feed them early morning and before dusk.
#  Detected Language: en
#
#
#  NER Entities: [('chickens', 'ANIMAL')]
#
#  Disambiguated 'feed': feed_1
#
# --------------------------------------------------------------------------------
